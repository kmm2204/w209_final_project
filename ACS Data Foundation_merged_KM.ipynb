# %% [markdown]
# # Census API Metric Codes
#
# | Race | Code |
# |------|------|
# | Total|B03002_001E|
# | Black|B03002_004E|
# | Asian|B03002_006E|
# | Native Hawaiian Pacific Islander|B03002_007E|
# | Other|B03002_008E|
# | Hispanic or Latino|B03002_012E|
# | 2 or More Races|B03002_010E|
#
# | Citizenship | Code |
# |------|------|
# | Total| B05001_001E
# | Not a u.s. Citizen|B05001_006E|
#
# | Income | Code |
# |------|------|
# | Total income population|B05010_001E|
# | Under poverty line|B05010_002E|
#
# | Education | Code |
# |------|------|
# | Less than HS graduate |B07009_002E|
# | High school graduate |B07009_003E|
# | Some college or associate's degree |B07009_004E|
# | Grad or professional degree |B07009_006E|
#
# | Under 5 | Code |
# |------|------|
# | Total |B01001_001E|
# | Male under 5 |B01001_003E|
# | Female under 5 |B01001_027E|
#
# | Housing | Code |
# |------|------|
# | Total |B07013_001E|
# | Renters |B07013_003E|

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import geopandas as gpd
import requests

from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.models import (ColumnDataSource,HoverTool, LogColorMapper)
from bokeh.palettes import Viridis6 as palette
from bokeh.tile_providers import STAMEN_TERRAIN
output_notebook()

#If you need to install anything
#import sys
#!conda install --yes --prefix {sys.prefix} numpy
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="589d7932-bc28-46af-b1af-238c7496c217">Loading BokehJS ...</span>
#     </div>

# %%
#Read in local files
#fcc = pd.read_csv("/Users/robertdeng/Google Drive/Data Science/W209/Project/fbd_us_without_satellite_dec2016_v1.csv", sep=",", encoding = "latin-1")
# census_shp = gpd.read_file("/Users/robertdeng/Google Drive/Data Science/W209/Project/Tract_2010Census_DP1/Tract_2010Census_DP1.shp")

# %% [markdown]
# Let's first check the availability of state data and store the missing url requests in a list

# %%
full_state_test = ["%.2d" % i for i in range(1,57)]
bad_apples = []
def state_checker(full_state_test):
    for i in full_state_test:
        url = ("https://api.census.gov/data/2015/acs5?get=NAME,B03002_001E"+
               "&for=tract:*&in=state:" + i + "&key=14ba39dd26088efd8d54c4f01d90023f2d4bfc6d")
        response_code = requests.get(url).status_code
        if response_code != 200:
            bad_apples.append([i, response_code])
state_checker(full_state_test)
print("These states return no content. Bad Apples :(\n", bad_apples)
# Out:
# These states return no content. Bad Apples :(
#  [['03', 204], ['07', 204], ['14', 204], ['43', 204], ['52', 204]]

# %% [markdown]
# 3, 7, 14, 43, 52 are missing, but all the states should be in there if we go up to 56
#
# https://www.census.gov/geo/reference/ansi_statetables.html

# %%
def pull_census(state, url_yes_no):
    url = ("https://api.census.gov/data/2015/acs5?get=NAME,B03002_001E,B03002_004E,B03002_006E," +
           "B03002_007E,B03002_008E,B03002_010E,B03002_012E," + #raceethicity
           "B05001_001E,B05001_006E," + #citizenship
           "B05002_013E" #foreign born
           "B05010_001E,B05010_002E," + #povertyline
           "B07009_001E,B07009_002E,B07009_003E,B07009_004E,B07009_006E," + #edu
           "B07013_001E,B07013_003E,"+ #renter
           "B01001_001E,B01001_003E,B01001_027E" + #under5 
           "&for=tract:*&in=state:" + state + "&key=14ba39dd26088efd8d54c4f01d90023f2d4bfc6d")
    if url_yes_no:
        print(url)        
    html = requests.get(url).json()
    return html

# %%
# pull_census("01", False)

# %%
#Make a master list range and remove the bad apples
master_list = ["%.2d" % i for i in range(1,57)]
master_list = [i for i in master_list if i not in [bad_apples[i][0] for i in range(len(bad_apples))]]

#Then stitch together all the data frames for the remaining dataset
for i in master_list:
    if i == "01":
        newstate = pull_census(i, False)
        master = pd.DataFrame(newstate, columns = newstate[0])[1:]
    elif i != "01":
        newstate = pull_census(i, False)
        master = master.append(pd.DataFrame(newstate, columns = newstate[0])[1:])

# %%
#Column Creation
master["GEOID"] = master['state'] + master['county'] + master['tract']
master["County Name"] = master["NAME"].str.split(",").str[1]
master["State Name"] = master["NAME"].str.split(",").str[2]

# %%
master.columns = ['Name', 'Total_all_race', 'Black', 'Asian', 'Native_Hawaiian_Pacific_Islander', 'Other', 'Two_or_More_Races', 'Hispanic_or_Latino', 
                  'Total_citizen', 'Not_a_us_Citizen',
                  'Total_born', 'Total_foreign_born',
                  'Total_income_population', "Total_under_poverty_line",
                  'Total_edu','Less_than_HS', 'HS_grad', 'College_grad', 'Graduate_or_professional',
                  'Total_housing', 'renters', 
                  'Total_pop_all_age','Total_male_under5','Total_female_under5',
                  'state', 'county', 'tract', 'GEOID', 'County Name', 'State Name']

# %%
master.head()
# Out:
#                                         Name Total_all_race Black Asian  \
# 1  Census Tract 201, Autauga County, Alabama           1948   150    12
# 2  Census Tract 202, Autauga County, Alabama           2156  1149    50
# 3  Census Tract 203, Autauga County, Alabama           2968   551    41
# 4  Census Tract 204, Autauga County, Alabama           4423   162     0
# 5  Census Tract 205, Autauga County, Alabama          10763  2674   412
#
#   Native_Hawaiian_Pacific_Islander Other Two_or_More_Races Hispanic_or_Latino  \
# 1                                0     0                 0                 17
# 2                                0     0                 0                 17
# 3                                8     0                 0                  0
# 4                                0    48                 5                464
# 5                                0     0                49                 80
#
#   Total_citizen Not_a_us_Citizen    ...     renters Total_pop_all_age  \
# 1          1948               27    ...         538              1948
# 2          2156               37    ...         754              2156
# 3          2968               15    ...         864              2968
# 4          4423               33    ...         836              4423
# 5         10763              188    ...        4611             10763
#
#   Total_male_under5 Total_female_under5 state county   tract        GEOID  \
# 1                30                  46    01    001  020100  01001020100
# 2                26                  40    01    001  020200  01001020200
# 3                38                  25    01    001  020300  01001020300
# 4               102                  93    01    001  020400  01001020400
# 5               403                 402    01    001  020500  01001020500
#
#        County Name State Name
# 1   Autauga County    Alabama
# 2   Autauga County    Alabama
# 3   Autauga County    Alabama
# 4   Autauga County    Alabama
# 5   Autauga County    Alabama
#
# [5 rows x 28 columns]

# %%
pdb = pd.read_csv("pdb2016trv8_us.csv", sep = ",", encoding = "latin-1",dtype={'GIDTR':object})

# %%
pdb.head()
# Out:
#          GIDTR  State State_name  County     County_name  Tract  Flag  \
# 0  01001020100      1    Alabama       1  Autauga County  20100   NaN
# 1  01001020200      1    Alabama       1  Autauga County  20200   NaN
# 2  01001020300      1    Alabama       1  Autauga County  20300   NaN
# 3  01001020400      1    Alabama       1  Autauga County  20400   NaN
# 4  01001020500      1    Alabama       1  Autauga County  20500   NaN
#
#    Num_BGs_in_Tract  LAND_AREA  AIAN_LAND               ...                 \
# 0               2.0      3.788        0.0               ...
# 1               2.0      1.290        0.0               ...
# 2               2.0      2.065        0.0               ...
# 3               4.0      2.464        0.0               ...
# 4               3.0      4.401        0.0               ...
#
#    pct_TEA_MailOutMailBack_CEN_2010  pct_TEA_Update_Leave_CEN_2010  \
# 0                             100.0                            NaN
# 1                             100.0                            NaN
# 2                             100.0                            NaN
# 3                             100.0                            NaN
# 4                             100.0                            NaN
#
#    pct_Census_Mail_Returns_CEN_2010  pct_Vacants_CEN_2010  \
# 0                             68.25                  1.92
# 1                             68.82                  2.28
# 2                             72.95                  1.67
# 3                             77.64                  1.46
# 4                             70.97                  2.16
#
#    pct_Deletes_CEN_2010  pct_Census_UAA_CEN_2010  pct_Mailback_Count_CEN_2010  \
# 0                   0.0                    16.39                        81.69
# 1                   0.0                    13.07                        84.65
# 2                   0.0                     6.53                        91.79
# 3                   0.0                     5.51                        93.03
# 4                   0.0                     5.96                        91.87
#
#    pct_FRST_FRMS_CEN_2010  pct_RPLCMNT_FRMS_CEN_2010  \
# 0                   61.84                       6.40
# 1                   60.79                       8.03
# 2                   72.95                       0.00
# 3                   77.64                       0.00
# 4                   70.97                       0.00
#
#    pct_BILQ_Mailout_count_CEN_2010
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
#
# [5 rows x 562 columns]

# %%
# pdb['Low_Response_Score']

# %%
# list(pdb.columns.values)

# %%
# pdb['pct_Mailback_Count_CEN_2010']

# %%
# pdb2=pdb[['GIDTR','pct_Mailback_Count_CEN_2010','Low_Response_Score']]  # df2 but only with columns x, a, and b

# pdb2

# %%
master_merged = master.merge(pdb2, left_on = "GEOID", right_on = "GIDTR", how = "left")

# %%
master_merged
# Out:
#                                                    Name Total_all_race Black  \
# 0             Census Tract 201, Autauga County, Alabama           1948   150
# 1             Census Tract 202, Autauga County, Alabama           2156  1149
# 2             Census Tract 203, Autauga County, Alabama           2968   551
# 3             Census Tract 204, Autauga County, Alabama           4423   162
# 4             Census Tract 205, Autauga County, Alabama          10763  2674
# 5             Census Tract 206, Autauga County, Alabama           3851   459
# 6             Census Tract 207, Autauga County, Alabama           2761   543
# 7          Census Tract 208.01, Autauga County, Alabama           3187   341
# 8          Census Tract 208.02, Autauga County, Alabama          10915   917
# 9             Census Tract 209, Autauga County, Alabama           5668   688
# 10            Census Tract 210, Autauga County, Alabama           3286   812
# 11            Census Tract 211, Autauga County, Alabama           3295  1790
# 12            Census Tract 101, Baldwin County, Alabama           3829   681
# 13            Census Tract 102, Baldwin County, Alabama           2869   299
# 14            Census Tract 103, Baldwin County, Alabama           7455  1014
# 15            Census Tract 104, Baldwin County, Alabama           4537   198
# 16            Census Tract 105, Baldwin County, Alabama           5321   686
# 17            Census Tract 106, Baldwin County, Alabama           3398  2125
# 18         Census Tract 107.01, Baldwin County, Alabama           7813   218
# 11        0                                0     0                 0
# 12        0                                0     0                 0
# 13        0                                0     0                 0
# 14        0                                0     0                 0
# 15       10                                0     0                 0
# 16       20                                0     0                11
# 17        0                                0     0                 0
# 18       25                                0     0                 0
# 19      269                                0    84               467
# 20       18                                0     0                 7
# 21      175                                0     0                 0
# 22        9                                0     0                 0
# 23        0                                0     5                 0
# 24       19                                0     0                 0
# 25       19                                0     0                 0
# 26        0                                0     6                 0
# 27        0                                0     3                 0
# 28       27                                0    37                 0
# 29        0                                0     0                 0
# ...     ...                              ...   ...               ...
# 73047    39                                0     0                 0
# 73048   111                                0     0                 0
# 73049     0                                0     0                 0
# 73050     0                                0     0                 4
# 73051     3                                2     0                 0
# 73052    50                                0     0                 0
# 73053    23                                0     0                 0
# 73054     0                                0     0                 0
# 73055    20                                0     0                 0
# 73056     0                                0     0                 0
# 73057   141                              225     0                 0
# 73058   108                                0     0                 0
# 73059    17                                0     0                 0
# 73060    16                                4     0                 0
# 73061     0                                0     0                 0
# 73062    42                                0    13                 0
# 73063     0                                0     0                 0
# 73064    17                                0     0                 0
# 73065    22                                0     7                 0
# 73066    19                                0     1                 0
# 73067   382                                0     0                 0
# 73068     1                                0     0                 0
# 73069     0                                0     0                 0
# 73070    25                                0     0                 0
# 73071     0                                0     0                 0
# 73072     0                                0     0                 0
# 73073     0                                0     0                 0
# 73074    14                                0     0                43
# 73075    10                                0     0                 0
# 73076    28                                0     0                 0
#
#       Hispanic_or_Latino Total_citizen Not_a_us_Citizen        ...          \
# 0                     17          1948               27        ...
# 1                     17          2156               37        ...
# 2                      0          2968               15        ...
# 3                    464          4423               33        ...
# 4                     80         10763              188        ...
# 5                    503          3851               88        ...
# 6                    104          2761               11        ...
# 7                     40          3187                0        ...
# 8                    150         10915               24        ...
# 9                     23          5668               23        ...
# 10                    25          3286               28        ...
# 11                    17          3295                0        ...
# 12                    10          3829                0        ...
# 13                    38          2869               15        ...
# 14                    39          7455               40        ...
# 15                   222          4537               86        ...
# 16                    68          5321               10        ...
# 17                   119          3398              119        ...
# 18                   360          7813              134        ...
# 19                   932         16099             1008        ...
# 20                   322          5411               96        ...
# 21                   233          9403              129        ...
# 22                     0          7645               49        ...
# 23                   350          5810               77        ...
# 24                   482          6949              218        ...
# 25                   664          7814              244        ...
# 26                   317          5029               78        ...
# 27                   184          4195               51        ...
# 28                   399          9220               43        ...
# 29                    50          4181               60        ...
# ...                  ...           ...              ...        ...
# 73047                 63          3812               30        ...
# 73048                601          5737              120        ...
# 73049                 99          6919               24        ...
# 73050                222          4967                7        ...
# 73051                317          4184               79        ...
# 73052                460          5933              183        ...
# 73053                267          2749               50        ...
# 73054               1182          4695              419        ...
# 73055                509          3701               25        ...
# 73056                502          3739              183        ...
# 73057               1022          5170              312        ...
# 73058                621          7332               33        ...
# 73059                655          4553              141        ...
# 73060                874          3165              347        ...
# 73061                235          2118              112        ...
# 73062                847          3244              169        ...
# 73063                146          2509               15        ...
# 73064                196          1797               29        ...
# 73065                250          4830              111        ...
# 73066                522          2396              361        ...
# 73067               1461          7099              781        ...
# 73068               1145          7986              634        ...
# 73069                248          6629               24        ...
# 73070                457          7220               44        ...
# 73071               1153          7081              300        ...
# 73072                401          3256              130        ...
# 73073                297          2578               12        ...
# 73074                477          2566              108        ...
# 73075                 84          3442               11        ...
# 73076                150          3710                9        ...
#
#       Total_female_under5 state county   tract        GEOID  \
# 0                      46    01    001  020100  01001020100
# 1                      40    01    001  020200  01001020200
# 2                      25    01    001  020300  01001020300
# 3                      93    01    001  020400  01001020400
# 4                     402    01    001  020500  01001020500
# 5                     123    01    001  020600  01001020600
# 6                     213    01    001  020700  01001020700
# 7                      38    01    001  020801  01001020801
# 8                     319    01    001  020802  01001020802
# 9                     191    01    001  020900  01001020900
# 10                     27    01    001  021000  01001021000
# 11                     39    01    001  021100  01001021100
# 12                     46    01    003  010100  01003010100
# 13                     70    01    003  010200  01003010200
# 14                    254    01    003  010300  01003010300
# 15                     99    01    003  010400  01003010400
# 16                    124    01    003  010500  01003010500
# 17                    106    01    003  010600  01003010600
# 18                    183    01    003  010701  01003010701
# 19                    439    01    003  010703  01003010703
# 20                     99    01    003  010704  01003010704
# 21                    276    01    003  010705  01003010705
# 22                    404    01    003  010800  01003010800
# 23                    106    01    003  010903  01003010903
# 24                    282    01    003  010904  01003010904
# 25                    202    01    003  010905  01003010905
# 26                    193    01    003  010906  01003010906
# 27                     37    01    003  011000  01003011000
# 28                    476    01    003  011101  01003011101
# 29                    132    01    003  011102  01003011102
# ...                   ...   ...    ...     ...          ...
# 73047                 104    56    033  000300  56033000300
# 73048                 313    56    033  000400  56033000400
# 73049                  50    56    033  000500  56033000500
# 73050                 152    56    033  000600  56033000600
# 73051                 102    56    035  000101  56035000101
# 73052                 154    56    035  000102  56035000102
# 73053                 121    56    037  970500  56037970500
# 73054                 166    56    037  970601  56037970601
# 73055                  63    56    037  970602  56037970602
# 73056                 113    56    037  970700  56037970700
# 73057                  61    56    037  970800  56037970800
# 73058                 536    56    037  970901  56037970901
# 73059                 200    56    037  970902  56037970902
# 73060                 232    56    037  970903  56037970903
# 73061                  38    56    037  971000  56037971000
# 73062                  26    56    037  971100  56037971100
# 73063                  64    56    037  971200  56037971200
# 73064                  42    56    037  971600  56037971600
# 73065                 135    56    039  967600  56039967600
# 73066                  69    56    039  967701  56039967701
# 73067                 129    56    039  967702  56039967702
# 73068                 408    56    039  967800  56039967800
# 73069                 333    56    041  975200  56041975200
# 73070                 293    56    041  975300  56041975300
# 73071                 111    56    041  975400  56041975400
# 73072                  33    56    043  000200  56043000200
# 73073                 111    56    043  000301  56043000301
# 73074                  63    56    043  000302  56043000302
# 73075                  82    56    045  951100  56045951100
# 73076                 197    56    045  951300  56045951300
#
#               County Name State Name        GIDTR pct_Mailback_Count_CEN_2010  \
# 0          Autauga County    Alabama  01001020100                       81.69
# 1          Autauga County    Alabama  01001020200                       84.65
# 2          Autauga County    Alabama  01001020300                       91.79
# 3          Autauga County    Alabama  01001020400                       93.03
# 4          Autauga County    Alabama  01001020500                       91.87
# 5          Autauga County    Alabama  01001020600                       82.91
# 6          Autauga County    Alabama  01001020700                       81.61
# 7          Autauga County    Alabama  01001020801                       84.32
# 8          Autauga County    Alabama  01001020802                       84.49
# 9          Autauga County    Alabama  01001020900                       77.27
# 10         Autauga County    Alabama  01001021000                       69.82
# 11         Autauga County    Alabama  01001021100                       62.62
# 12         Baldwin County    Alabama  01003010100                       65.79
# 13         Baldwin County    Alabama  01003010200                       61.57
# 14         Baldwin County    Alabama  01003010300                       72.85
# 15         Baldwin County    Alabama  01003010400                       74.24
# 16         Baldwin County    Alabama  01003010500                       82.77
# 17         Baldwin County    Alabama  01003010600                       75.45
# 18         Baldwin County    Alabama  01003010701                       82.89
# 19         Baldwin County    Alabama  01003010703                       77.95
# 20         Baldwin County    Alabama  01003010704                       88.94
# 21         Baldwin County    Alabama  01003010705                       78.12
# 22         Baldwin County    Alabama  01003010800                       65.00
# 23         Baldwin County    Alabama  01003010903                       73.41
# 24         Baldwin County    Alabama  01003010904                       77.37
# 25         Baldwin County    Alabama  01003010905                       68.45
# 26         Baldwin County    Alabama  01003010906                       72.90
# 27         Baldwin County    Alabama  01003011000                       66.05
# 28         Baldwin County    Alabama  01003011101                       86.43
# 29         Baldwin County    Alabama  01003011102                       82.76
# ...                   ...        ...          ...                         ...
# 73047     Sheridan County    Wyoming  56033000300                       87.10
# 73048     Sheridan County    Wyoming  56033000400                       89.49
# 73049     Sheridan County    Wyoming  56033000500                       75.26
# 73050     Sheridan County    Wyoming  56033000600                       82.25
# 73051     Sublette County    Wyoming  56035000101                       64.01
# 73052     Sublette County    Wyoming  56035000102                       61.68
# 73053   Sweetwater County    Wyoming  56037970500                       71.90
# 73054   Sweetwater County    Wyoming  56037970601                       84.23
# 73055   Sweetwater County    Wyoming  56037970602                       93.81
# 73056   Sweetwater County    Wyoming  56037970700                       80.04
# 73057   Sweetwater County    Wyoming  56037970800                       77.31
# 73058   Sweetwater County    Wyoming  56037970901                       77.31
# 73059   Sweetwater County    Wyoming  56037970902                       88.88
# 73060   Sweetwater County    Wyoming  56037970903                       69.42
# 73061   Sweetwater County    Wyoming  56037971000                       80.45
# 73062   Sweetwater County    Wyoming  56037971100                       81.75
# 73063   Sweetwater County    Wyoming  56037971200                       86.92
# 73064   Sweetwater County    Wyoming  56037971600                       56.56
# 73065        Teton County    Wyoming  56039967600                       49.78
# 73066        Teton County    Wyoming  56039967701                       78.79
# 73067        Teton County    Wyoming  56039967702                       65.64
# 73068        Teton County    Wyoming  56039967800                       79.43
# 73069        Uinta County    Wyoming  56041975200                       82.43
# 73070        Uinta County    Wyoming  56041975300                       68.25
# 73071        Uinta County    Wyoming  56041975400                       74.02
# 73072     Washakie County    Wyoming  56043000200                       76.20
# 73073     Washakie County    Wyoming  56043000301                       90.28
# 73074     Washakie County    Wyoming  56043000302                       90.32
# 73075       Weston County    Wyoming  56045951100                       76.87
# 73076       Weston County    Wyoming  56045951300                       83.88
#
#       Low_Response_Score
# 0                   17.9
# 1                   23.2
# 2                   17.9
# 3                   13.5
# 4                   19.0
# 5                   20.2
# 6                   22.8
# 7                   18.5
# 8                   18.2
# 9                   20.0
# 10                  21.0
# 11                  23.0
# 12                  20.9
# 13                  21.3
# 14                  19.1
# 15                  18.6
# 16                  18.5
# 17                  26.5
# 18                  14.9
# 19                  17.8
# 20                  15.4
# 21                  20.8
# 22                  17.6
# 23                  20.6
# 24                  18.2
# 25                  20.8
# 26                  18.8
# 27                  20.2
# 28                  15.6
# 29                  16.7
# ...                  ...
# 73047               16.8
# 73048               19.7
# 73049               17.4
# 73050               18.9
# 73051               23.1
# 73052               22.3
# 73053               23.2
# 73054               24.1
# 73055               17.4
# 73056               20.4
# 73057               26.0
# 73058               21.6
# 73059               22.3
# 73060               27.3
# 73061               24.2
# 73062               20.7
# 73063               18.0
# 73064               24.4
# 73065               21.6
# 73066               25.9
# 73067               24.2
# 73068               25.7
# 73069               19.5
# 73070               22.7
# 73071               22.2
# 73072               19.9
# 73073               18.6
# 73074               16.7
# 73075               18.8
# 73076               19.3
#
# [73077 rows x 31 columns]

# %%
fcc = pd.read_csv("tract_map_jun_2016.csv", sep=",", encoding = "latin-1", dtype={'tractcode': object})

# %%
# fcc.head()

# %%
master_merged_final = master_merged.merge(fcc, left_on = "GEOID", right_on = "tractcode", how = "left")

# %%
master_merged_final
# Out:
#                                                    Name Total_all_race Black  \
# 0             Census Tract 201, Autauga County, Alabama           1948   150
# 1             Census Tract 202, Autauga County, Alabama           2156  1149
# 2             Census Tract 203, Autauga County, Alabama           2968   551
# 3             Census Tract 204, Autauga County, Alabama           4423   162
# 4             Census Tract 205, Autauga County, Alabama          10763  2674
# 5             Census Tract 206, Autauga County, Alabama           3851   459
# 6             Census Tract 207, Autauga County, Alabama           2761   543
# 7          Census Tract 208.01, Autauga County, Alabama           3187   341
# 8          Census Tract 208.02, Autauga County, Alabama          10915   917
# 9             Census Tract 209, Autauga County, Alabama           5668   688
# 10            Census Tract 210, Autauga County, Alabama           3286   812
# 11            Census Tract 211, Autauga County, Alabama           3295  1790
# 12            Census Tract 101, Baldwin County, Alabama           3829   681
# 13            Census Tract 102, Baldwin County, Alabama           2869   299
# 14            Census Tract 103, Baldwin County, Alabama           7455  1014
# 15            Census Tract 104, Baldwin County, Alabama           4537   198
# 16            Census Tract 105, Baldwin County, Alabama           5321   686
# 17            Census Tract 106, Baldwin County, Alabama           3398  2125
# 18         Census Tract 107.01, Baldwin County, Alabama           7813   218
# 19         Census Tract 107.03, Baldwin County, Alabama          16099   715
# 20         Census Tract 107.04, Baldwin County, Alabama           5411   654
# 21         Census Tract 107.05, Baldwin County, Alabama           9403  1616
# 22            Census Tract 108, Baldwin County, Alabama           7645  2392
# 23         Census Tract 109.03, Baldwin County, Alabama           5810   885
# 24         Census Tract 109.04, Baldwin County, Alabama           6949   111
# 25         Census Tract 109.05, Baldwin County, Alabama           7814   529
# 26         Census Tract 109.06, Baldwin County, Alabama           5029   123
# 29        0                                0     0                 0
# ...     ...                              ...   ...               ...
# 73047    39                                0     0                 0
# 73048   111                                0     0                 0
# 73049     0                                0     0                 0
# 73050     0                                0     0                 4
# 73051     3                                2     0                 0
# 73052    50                                0     0                 0
# 73053    23                                0     0                 0
# 73054     0                                0     0                 0
# 73055    20                                0     0                 0
# 73056     0                                0     0                 0
# 73057   141                              225     0                 0
# 73058   108                                0     0                 0
# 73059    17                                0     0                 0
# 73060    16                                4     0                 0
# 73061     0                                0     0                 0
# 73062    42                                0    13                 0
# 73063     0                                0     0                 0
# 73064    17                                0     0                 0
# 73065    22                                0     7                 0
# 73066    19                                0     1                 0
# 73067   382                                0     0                 0
# 73068     1                                0     0                 0
# 73069     0                                0     0                 0
# 73070    25                                0     0                 0
# 73071     0                                0     0                 0
# 73072     0                                0     0                 0
# 73073     0                                0     0                 0
# 73074    14                                0     0                43
# 73075    10                                0     0                 0
# 73076    28                                0     0                 0
#
#       Hispanic_or_Latino Total_citizen Not_a_us_Citizen    ...      tract  \
# 0                     17          1948               27    ...     020100
# 1                     17          2156               37    ...     020200
# 2                      0          2968               15    ...     020300
# 3                    464          4423               33    ...     020400
# 4                     80         10763              188    ...     020500
# 5                    503          3851               88    ...     020600
# 6                    104          2761               11    ...     020700
# 7                     40          3187                0    ...     020801
# 8                    150         10915               24    ...     020802
# 9                     23          5668               23    ...     020900
# 10                    25          3286               28    ...     021000
# 11                    17          3295                0    ...     021100
# 12                    10          3829                0    ...     010100
# 13                    38          2869               15    ...     010200
# 14                    39          7455               40    ...     010300
# 15                   222          4537               86    ...     010400
# 16                    68          5321               10    ...     010500
# 17                   119          3398              119    ...     010600
# 18                   360          7813              134    ...     010701
# 19                   932         16099             1008    ...     010703
# 20                   322          5411               96    ...     010704
# 21                   233          9403              129    ...     010705
# 22                     0          7645               49    ...     010800
# 23                   350          5810               77    ...     010903
# 24                   482          6949              218    ...     010904
# 25                   664          7814              244    ...     010905
# 26                   317          5029               78    ...     010906
# 27                   184          4195               51    ...     011000
# 28                   399          9220               43    ...     011101
# 29                    50          4181               60    ...     011102
# ...                  ...           ...              ...    ...        ...
# 73047                 63          3812               30    ...     000300
# 73048                601          5737              120    ...     000400
# 73049                 99          6919               24    ...     000500
# 73050                222          4967                7    ...     000600
# 73051                317          4184               79    ...     000101
# 73052                460          5933              183    ...     000102
# 73053                267          2749               50    ...     970500
# 73054               1182          4695              419    ...     970601
# 73055                509          3701               25    ...     970602
# 73056                502          3739              183    ...     970700
# 73057               1022          5170              312    ...     970800
# 73058                621          7332               33    ...     970901
# 73059                655          4553              141    ...     970902
# 73060                874          3165              347    ...     970903
# 73061                235          2118              112    ...     971000
# 73062                847          3244              169    ...     971100
# 73063                146          2509               15    ...     971200
# 73064                196          1797               29    ...     971600
# 73065                250          4830              111    ...     967600
# 73066                522          2396              361    ...     967701
# 73067               1461          7099              781    ...     967702
# 73068               1145          7986              634    ...     967800
# 73069                248          6629               24    ...     975200
# 73070                457          7220               44    ...     975300
# 73071               1153          7081              300    ...     975400
# 73072                401          3256              130    ...     000200
# 73073                297          2578               12    ...     000301
# 73074                477          2566              108    ...     000302
# 73075                 84          3442               11    ...     951100
# 73076                150          3710                9    ...     951300
#
#              GEOID         County Name State Name        GIDTR  \
# 0      01001020100      Autauga County    Alabama  01001020100
# 1      01001020200      Autauga County    Alabama  01001020200
# 2      01001020300      Autauga County    Alabama  01001020300
# 3      01001020400      Autauga County    Alabama  01001020400
# 4      01001020500      Autauga County    Alabama  01001020500
# 5      01001020600      Autauga County    Alabama  01001020600
# 6      01001020700      Autauga County    Alabama  01001020700
# 7      01001020801      Autauga County    Alabama  01001020801
# 8      01001020802      Autauga County    Alabama  01001020802
# 9      01001020900      Autauga County    Alabama  01001020900
# 10     01001021000      Autauga County    Alabama  01001021000
# 11     01001021100      Autauga County    Alabama  01001021100
# 12     01003010100      Baldwin County    Alabama  01003010100
# 13     01003010200      Baldwin County    Alabama  01003010200
# 14     01003010300      Baldwin County    Alabama  01003010300
# 15     01003010400      Baldwin County    Alabama  01003010400
# 16     01003010500      Baldwin County    Alabama  01003010500
# 17     01003010600      Baldwin County    Alabama  01003010600
# 18     01003010701      Baldwin County    Alabama  01003010701
# 19     01003010703      Baldwin County    Alabama  01003010703
# 20     01003010704      Baldwin County    Alabama  01003010704
# 21     01003010705      Baldwin County    Alabama  01003010705
# 22     01003010800      Baldwin County    Alabama  01003010800
# 23     01003010903      Baldwin County    Alabama  01003010903
# 24     01003010904      Baldwin County    Alabama  01003010904
# 25     01003010905      Baldwin County    Alabama  01003010905
# 26     01003010906      Baldwin County    Alabama  01003010906
# 27     01003011000      Baldwin County    Alabama  01003011000
# 28     01003011101      Baldwin County    Alabama  01003011101
# 29     01003011102      Baldwin County    Alabama  01003011102
# ...            ...                 ...        ...          ...
# 73047  56033000300     Sheridan County    Wyoming  56033000300
# 73048  56033000400     Sheridan County    Wyoming  56033000400
# 73049  56033000500     Sheridan County    Wyoming  56033000500
# 73050  56033000600     Sheridan County    Wyoming  56033000600
# 73051  56035000101     Sublette County    Wyoming  56035000101
# 73052  56035000102     Sublette County    Wyoming  56035000102
# 73053  56037970500   Sweetwater County    Wyoming  56037970500
# 73054  56037970601   Sweetwater County    Wyoming  56037970601
# 73055  56037970602   Sweetwater County    Wyoming  56037970602
# 73056  56037970700   Sweetwater County    Wyoming  56037970700
# 73057  56037970800   Sweetwater County    Wyoming  56037970800
# 73058  56037970901   Sweetwater County    Wyoming  56037970901
# 73059  56037970902   Sweetwater County    Wyoming  56037970902
# 73060  56037970903   Sweetwater County    Wyoming  56037970903
# 73061  56037971000   Sweetwater County    Wyoming  56037971000
# 73062  56037971100   Sweetwater County    Wyoming  56037971100
# 73063  56037971200   Sweetwater County    Wyoming  56037971200
# 73064  56037971600   Sweetwater County    Wyoming  56037971600
# 73065  56039967600        Teton County    Wyoming  56039967600
# 73066  56039967701        Teton County    Wyoming  56039967701
# 73067  56039967702        Teton County    Wyoming  56039967702
# 73072                       76.20               19.9  56043000200      4.0
# 73073                       90.28               18.6  56043000301      3.0
# 73074                       90.32               16.7  56043000302      5.0
# 73075                       76.87               18.8  56045951100      4.0
# 73076                       83.88               19.3  56045951300      3.0
#
#       pcat_10x1
# 0           4.0
# 1           3.0
# 2           4.0
# 3           4.0
# 4           4.0
# 5           4.0
# 6           4.0
# 7           3.0
# 8           4.0
# 9           2.0
# 10          2.0
# 11          2.0
# 12          1.0
# 13          2.0
# 14          3.0
# 15          2.0
# 16          3.0
# 17          2.0
# 18          3.0
# 19          4.0
# 20          4.0
# 21          4.0
# 22          4.0
# 23          1.0
# 24          2.0
# 25          2.0
# 26          2.0
# 27          1.0
# 28          3.0
# 29          4.0
# ...         ...
# 73047       4.0
# 73048       4.0
# 73049       2.0
# 73050       2.0
# 73051       1.0
# 73052       1.0
# 73053       2.0
# 73054       2.0
# 73055       2.0
# 73056       2.0
# 73057       2.0
# 73058       2.0
# 73059       3.0
# 73060       3.0
# 73061       1.0
# 73062       2.0
# 73063       2.0
# 73064       1.0
# 73065       4.0
# 73066       5.0
# 73067       5.0
# 73068       5.0
# 73069       5.0
# 73070       4.0
# 73071       3.0
# 73072       2.0
# 73073       3.0
# 73074       3.0
# 73075       1.0
# 73076       1.0
#
# [73077 rows x 34 columns]

# %%
list(master_merged_final.columns.values)
# Out:
# ['Name',
#  'Total_all_race',
#  'Black',
#  'Asian',
#  'Native_Hawaiian_Pacific_Islander',
#  'Other',
#  'Two_or_More_Races',
#  'Hispanic_or_Latino',
#  'Total_citizen',
#  'Not_a_us_Citizen',
#  'Total_income_population',
#  'Total_under_poverty_line',
#  'Total_edu',
#  'Less_than_HS',
#  'HS_grad',
#  'College_grad',
#  'Graduate_or_professional',
#  'Total_housing',
#  'renters',
#  'Total_pop_all_age',
#  'Total_male_under5',
#  'Total_female_under5',
#  'state',
#  'county',
#  'tract',
#  'GEOID',
#  'County Name',
#  'State Name',
#  'GIDTR',
#  'pct_Mailback_Count_CEN_2010',
#  'Low_Response_Score',
#  'tractcode',
#  'pcat_all',
#  'pcat_10x1']

# %%
a=master_merged_final

# %%
master_merged_final[['Total_all_race',
 'Black',
 'Asian',
 'Native_Hawaiian_Pacific_Islander',
 'Other',
 'Two_or_More_Races',
 'Hispanic_or_Latino',
 'Total_citizen',
 'Not_a_us_Citizen',
 'Total_income_population',
 'Total_under_poverty_line',
 'Total_edu',
 'Less_than_HS',
 'HS_grad',
 'College_grad',
 'Graduate_or_professional',
 'Total_housing',
 'renters',
 'Total_pop_all_age',
 'Total_male_under5',
 'Total_female_under5',
 'pct_Mailback_Count_CEN_2010',
 'Low_Response_Score',
'pcat_all',
 'pcat_10x1']] = master_merged_final[['Total_all_race',
 'Black',
 'Asian',
 'Native_Hawaiian_Pacific_Islander',
 'Other',
 'Two_or_More_Races',
 'Hispanic_or_Latino',
 'Total_citizen',
 'Not_a_us_Citizen',
 'Total_income_population',
 'Total_under_poverty_line',
 'Total_edu',
 'Less_than_HS',
 'HS_grad',
 'College_grad',
 'Graduate_or_professional',
 'Total_housing',
 'renters',
 'Total_pop_all_age',
 'Total_male_under5',
 'Total_female_under5',
 'pct_Mailback_Count_CEN_2010',
 'Low_Response_Score',
'pcat_all',
 'pcat_10x1']].apply(pd.to_numeric)

# %%
a=master_merged_final

# %%
a['Total_minority']=a['Black']+a['Asian']+a['Native_Hawaiian_Pacific_Islander']+a['Other']+a['Two_or_More_Races']+a['Hispanic_or_Latino']

# %%
a['pct_minority']=a['Total_minority']/a['Total_all_race']

# %%
a['pct_not_citizen']=a['Not_a_us_Citizen']/ a['Total_citizen']

# %%
a['Total_under_5']=a['Total_male_under5']+a['Total_female_under5']

# %%
a['pct_under_5']=a['Total_under_5']/a['Total_pop_all_age']

# %%
a['pct_renters']=a['renters']/a['Total_housing']

# %%
a.pct_minority.quantile(0.8)
# Out:
# 0.648477233213002

# %%
a
# Out:
#                                                    Name  Total_all_race  \
# 0             Census Tract 201, Autauga County, Alabama            1948
# 1             Census Tract 202, Autauga County, Alabama            2156
# 2             Census Tract 203, Autauga County, Alabama            2968
# 3             Census Tract 204, Autauga County, Alabama            4423
# 4             Census Tract 205, Autauga County, Alabama           10763
# 5             Census Tract 206, Autauga County, Alabama            3851
# 6             Census Tract 207, Autauga County, Alabama            2761
# 7          Census Tract 208.01, Autauga County, Alabama            3187
# 8          Census Tract 208.02, Autauga County, Alabama           10915
# 9             Census Tract 209, Autauga County, Alabama            5668
# 10            Census Tract 210, Autauga County, Alabama            3286
# 11            Census Tract 211, Autauga County, Alabama            3295
# 12            Census Tract 101, Baldwin County, Alabama            3829
# 13            Census Tract 102, Baldwin County, Alabama            2869
# 14            Census Tract 103, Baldwin County, Alabama            7455
# 15            Census Tract 104, Baldwin County, Alabama            4537
# 16            Census Tract 105, Baldwin County, Alabama            5321
# 17            Census Tract 106, Baldwin County, Alabama            3398
# 18         Census Tract 107.01, Baldwin County, Alabama            7813
# 19         Census Tract 107.03, Baldwin County, Alabama           16099
# 20         Census Tract 107.04, Baldwin County, Alabama            5411
# 21         Census Tract 107.05, Baldwin County, Alabama            9403
# 22            Census Tract 108, Baldwin County, Alabama            7645
# 23         Census Tract 109.03, Baldwin County, Alabama            5810
# 24         Census Tract 109.04, Baldwin County, Alabama            6949
# 25         Census Tract 109.05, Baldwin County, Alabama            7814
# 26         Census Tract 109.06, Baldwin County, Alabama            5029
# 27            Census Tract 110, Baldwin County, Alabama            4195
# 28         Census Tract 111.01, Baldwin County, Alabama            9220
# 29         Census Tract 111.02, Baldwin County, Alabama            4181
# ...                                                 ...             ...
# 73047          Census Tract 3, Sheridan County, Wyoming            3812
# 73048          Census Tract 4, Sheridan County, Wyoming            5737
# 73049          Census Tract 5, Sheridan County, Wyoming            6919
# 73050          Census Tract 6, Sheridan County, Wyoming            4967
# 73051       Census Tract 1.01, Sublette County, Wyoming            4184
# 73052       Census Tract 1.02, Sublette County, Wyoming            5933
# 73053     Census Tract 9705, Sweetwater County, Wyoming            2749
# 15        ...                     18.6  01003010400       4.0        2.0
# 16        ...                     18.5  01003010500       4.0        3.0
# 17        ...                     26.5  01003010600       3.0        2.0
# 18        ...                     14.9  01003010701       5.0        3.0
# 19        ...                     17.8  01003010703       5.0        4.0
# 20        ...                     15.4  01003010704       5.0        4.0
# 21        ...                     20.8  01003010705       5.0        4.0
# 22        ...                     17.6  01003010800       5.0        4.0
# 23        ...                     20.6  01003010903       4.0        1.0
# 24        ...                     18.2  01003010904       4.0        2.0
# 25        ...                     20.8  01003010905       4.0        2.0
# 26        ...                     18.8  01003010906       4.0        2.0
# 27        ...                     20.2  01003011000       4.0        1.0
# 28        ...                     15.6  01003011101       5.0        3.0
# 29        ...                     16.7  01003011102       5.0        4.0
# ...       ...                      ...          ...       ...        ...
# 73047     ...                     16.8  56033000300       4.0        4.0
# 73048     ...                     19.7  56033000400       5.0        4.0
# 73049     ...                     17.4  56033000500       4.0        2.0
# 73050     ...                     18.9  56033000600       4.0        2.0
# 73051     ...                     23.1  56035000101       4.0        1.0
# 73052     ...                     22.3  56035000102       4.0        1.0
# 73053     ...                     23.2  56037970500       4.0        2.0
# 73054     ...                     24.1  56037970601       4.0        2.0
# 73055     ...                     17.4  56037970602       5.0        2.0
# 73056     ...                     20.4  56037970700       5.0        2.0
# 73057     ...                     26.0  56037970800       4.0        2.0
# 73058     ...                     21.6  56037970901       4.0        2.0
# 73059     ...                     22.3  56037970902       5.0        3.0
# 73060     ...                     27.3  56037970903       4.0        3.0
# 73061     ...                     24.2  56037971000       3.0        1.0
# 73062     ...                     20.7  56037971100       4.0        2.0
# 73063     ...                     18.0  56037971200       5.0        2.0
# 73064     ...                     24.4  56037971600       3.0        1.0
# 73065     ...                     21.6  56039967600       5.0        4.0
# 73066     ...                     25.9  56039967701       5.0        5.0
# 73067     ...                     24.2  56039967702       5.0        5.0
# 73068     ...                     25.7  56039967800       5.0        5.0
# 73069     ...                     19.5  56041975200       5.0        5.0
# 73070     ...                     22.7  56041975300       5.0        4.0
# 73071     ...                     22.2  56041975400       5.0        3.0
# 73072     ...                     19.9  56043000200       4.0        2.0
# 73073     ...                     18.6  56043000301       3.0        3.0
# 73074     ...                     16.7  56043000302       5.0        3.0
# 73075     ...                     18.8  56045951100       4.0        1.0
# 73076     ...                     19.3  56045951300       3.0        1.0
#
#        Total_minority  pct_minority  pct_not_citizen  Total_under_5  \
# 0                 179      0.091889         0.013860             76
# 1                1216      0.564007         0.017161             66
# 2                 600      0.202156         0.005054             63
# 3                 679      0.153516         0.007461            195
# 4                3215      0.298709         0.017467            805
# 5                 962      0.249805         0.022851            257
# 6                 678      0.245563         0.003984            284
# 7                 381      0.119548         0.000000             91
# 8                1067      0.097755         0.002199            748
# 9                 730      0.128793         0.004058            451
# 10                837      0.254717         0.008521            102
# 11               1807      0.548407         0.000000            104
# 12                691      0.180465         0.000000            164
# 13                337      0.117463         0.005228            187
# 14               1053      0.141247         0.005366            426
# 15                430      0.094776         0.018955            219
# 16                785      0.147529         0.001879            325
# 17               2244      0.660388         0.035021            386
# 18                603      0.077179         0.017151            424
# 19               2467      0.153239         0.062613            995
# 20               1001      0.184994         0.017742            259
# 21               2024      0.215250         0.013719            487
# 22               2401      0.314061         0.006409            596
# 23               1240      0.213425         0.013253            274
# 24                612      0.088070         0.031371            405
# 25               1212      0.155106         0.031226            358
# 26                446      0.088686         0.015510            304
# 27                416      0.099166         0.012157             89
# 28                648      0.070282         0.004664            715
# 29                 88      0.021048         0.014351            161
# ...               ...           ...              ...            ...
# 73047             111      0.029119         0.007870            267
# 73048             744      0.129685         0.020917            389
# 73049             102      0.014742         0.003469            286
# 73050             244      0.049124         0.001409            313
# 73051             322      0.076960         0.018881            255
# 73052             510      0.085960         0.030844            365
# 73053             354      0.128774         0.018188            233
# 73054            1189      0.253248         0.089244            243
# 73055             529      0.142934         0.006755            194
# 73056             509      0.136133         0.048944            245
# 73057            1517      0.293424         0.060348            106
# 73058             752      0.102564         0.004501            834
# 73059             672      0.147595         0.030969            590
# 73060             931      0.294155         0.109637            405
# 73061             235      0.110954         0.052880            127
# 73062             902      0.278052         0.052096            119
# 73063             237      0.094460         0.005978            169
# 73064             230      0.127991         0.016138             86
# 73065             306      0.063354         0.022981            266
# 73066             549      0.229132         0.150668            146
# 73067            1843      0.259614         0.110015            267
# 73068            1147      0.143626         0.079389            599
# 73069             264      0.039825         0.003620            610
# 73070             507      0.070222         0.006094            573
# 73071            1153      0.162830         0.042367            481
# 73072             458      0.140663         0.039926            142
# 73073             297      0.115206         0.004655            228
# 73074             534      0.208106         0.042089            102
# 73075             109      0.031668         0.003196            116
# 73076             178      0.047978         0.002426            345
#
#        pct_under_5  pct_renters
# 0         0.039014     0.277606
# 1         0.030612     0.381001
# 2         0.021226     0.294479
# 3         0.044088     0.190955
# 4         0.074793     0.440738
# 5         0.066736     0.288400
# 6         0.102861     0.342174
# 7         0.028553     0.180761
# 8         0.068530     0.192890
# 9         0.079570     0.178629
# 10        0.031041     0.160835
# 11        0.031563     0.153680
# 12        0.042831     0.077854
# 13        0.065180     0.203546
# 14        0.057143     0.178168
# 15        0.048270     0.140873
# 16        0.061079     0.326147
# 17        0.113596     0.431050
# 18        0.054269     0.174271
# 19        0.061805     0.262998
# 20        0.047865     0.310884
# 21        0.051792     0.478943
# 22        0.077959     0.388386
# 23        0.047160     0.300198
# 24        0.058282     0.178477
# 25        0.045815     0.361931
# 26        0.060449     0.234404
# 27        0.021216     0.176172
# 28        0.077549     0.250275
# 29        0.038508     0.100920
# ...            ...          ...
# 73047     0.070042     0.455178
# 73048     0.067805     0.284386
# 73049     0.041335     0.155933
# 73050     0.063016     0.258192
# 73051     0.060946     0.284932
# 73052     0.061520     0.248635
# 73053     0.084758     0.389384
# 73054     0.051757     0.329172
# 73055     0.052418     0.232158
# 73056     0.065526     0.209386
# 73057     0.020503     0.342498
# 73058     0.113748     0.169287
# 73059     0.129585     0.342014
# 73060     0.127962     0.504481
# 73061     0.059962     0.242728
# 73062     0.036683     0.323017
# 73063     0.067358     0.135135
# 73064     0.047858     0.359060
# 73065     0.055072     0.299251
# 73066     0.060935     0.627442
# 73067     0.037611     0.359156
# 73068     0.075006     0.450064
# 73069     0.092020     0.212173
# 73070     0.079363     0.222544
# 73071     0.067928     0.334105
# 73072     0.043612     0.172479
# 73073     0.088441     0.317787
# 73074     0.039751     0.238782
# 73075     0.033701     0.175096
# 73076     0.092992     0.192826
#
# [73077 rows x 40 columns]

# %% [markdown]
# # Shapefile

# %%
#Get Polygon coordinates
def getPolyCoords(row, geom, coord_type):
    """Returns the coordinates ('x' or 'y') of edges of a Polygon exterior"""
    if row[geom].type == 'Polygon':
    # Parse the exterior of the coordinate
        exterior = row[geom].exterior

        if coord_type == 'x':
        # Get the x coordinates of the exterior
            return list( exterior.coords.xy[0] )
        elif coord_type == 'y':
        # Get the y coordinates of the exterior
            return list( exterior.coords.xy[1] )       

#Create x, y coordinates for polygons
census_shp["x"] = census_shp.apply(getPolyCoords, geom="geometry", coord_type="x", axis=1)
census_shp["y"] = census_shp.apply(getPolyCoords, geom="geometry", coord_type="y", axis=1)

#x, y ranges
tract_bounds=census_shp.total_bounds
xlim = (tract_bounds[0],tract_bounds[2])
ylim = (tract_bounds[1],tract_bounds[3])

bounds = x_range,y_range = (xlim,ylim)

# %%
#NaN Checks
#nan_index = merged.index[np.isnan(merged.state.astype(float))].tolist()
#len(merged.index[np.isnan(merged.state.astype(float))].tolist())

# %%
merged = census_shp.merge(master, left_on = "GEOID10", right_on = "GEOID", how = "left", sort = True)
#merged.head()

# %%
#import pysal as ps
#pop = merged.Total_Population.astype(float)
#pop = pop[~np.isnan(pop)]

# %%
#popq = ps.Quantiles(pop,k=9)
#popq, popq.adcm

# %%
#popeq = ps.Equal_Interval(pop,k=9)
#popeq, popeq.adcm

# %%
#popfj = ps.Fisher_Jenks(pop,k=9)
#popfj, popfj.adcm

# %%
temp_stored_merged = merged
merged = merged[merged["state"] == "06"]

#http://geographyplanning.buffalostate.edu/Mix/Python/Visualization-PoorChildrenNY.html

merged_ys = merged['y'].tolist()
merged_xs = merged['x'].tolist()
merged_name = merged['NAMELSAD10'].tolist()
merged_pop = merged['Total_Population'].tolist()

color_mapper = LogColorMapper(palette=palette)

source = ColumnDataSource(
        data=dict(
            x=merged_xs,
            y=merged_ys,
            name=merged_name,
            population = merged_pop
        )
    )

TOOLS = "pan,wheel_zoom,box_zoom,reset,hover,save"

f = figure(
    plot_height=700, plot_width=800,
    title="Census 5 Year Test",
    tools=TOOLS,
    x_axis_location=None,
    y_axis_location=None,
    x_range=x_range,
    y_range=y_range)

f.title.text_font_style = "italic"
f.title.text_font_size = '14pt'
f.background_fill_color = 'gray'
f.grid.grid_line_color = None
f.add_tile(STAMEN_TERRAIN)

f.patches("x", "y",source=source, fill_color = {'field': 'population', 'transform': color_mapper},
          fill_alpha=0.7,line_color = 'white',line_width=0.5) 

hover = f.select_one(HoverTool)
hover.point_policy = "follow_mouse"
hover.tooltips = [
    ("Census Tract", "@name"),
    ("Population", "@population"),
]
show(f)
